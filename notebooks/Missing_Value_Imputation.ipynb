# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df  = pd.read_csv('/content/pakwheels_clean.csv')

# %%
# df = pd.read_csv('/content/pakwheels_cleaned.csv')

# %%
df.isnull().sum()
# Out:
# year                 0
# price                0
# Km_travelled         0
# fuel_type            0
# transmission         0
# city                 0
# color              635
# assembly             0
# engine               0
# body_type          162
# interior_scores      0
# exterior_scores      0
# safety_scores        0
# comfort_scores       0
# company              0
# dtype: int64

# %%
df[df['color'].isnull()]
# Out:
#        year  price  Km_travelled fuel_type transmission           city color  \
# 40     2018   0.53        128000    Petrol    Automatic         Lahore   NaN
# 50     2020   0.58         83600    Petrol    Automatic          Sindh   NaN
# 57     2022   0.69         65000    Petrol    Automatic      Islamabad   NaN
# 75     2022   0.62         24000    Petrol    Automatic        Karachi   NaN
# 80     2022   0.40          8000    Petrol    Automatic         Punjab   NaN
# ...     ...    ...           ...       ...          ...            ...   ...
# 11885  2012   0.28        145000    Petrol       Manual          Sindh   NaN
# 11886  2017   0.47        105000    Petrol    Automatic        Karachi   NaN
# 11889  2022   6.05         25000    Petrol    Automatic  Un-Registered   NaN
# 11901  2025   0.79         12000    Petrol    Automatic        Karachi   NaN
# 11906  2013   0.30        100000    Petrol       Manual         Lahore   NaN
#
# ...

# %%
df[df['body_type'].isnull()]
# Out:
#        year  price  Km_travelled fuel_type transmission           city  \
# 69     2007   0.22        139836    Petrol    Automatic      Islamabad
# 72     2019   0.29         50000    Petrol    Automatic         Punjab
# 123    1991   0.04        150000    Petrol       Manual        Karachi
# 125    2013   0.21        138000    Petrol    Automatic         Punjab
# 159    2022   0.38         24000    Hybrid    Automatic         Punjab
# ...     ...    ...           ...       ...          ...            ...
# 11612  2019   0.54        140000    Petrol    Automatic  Un-Registered
# 11620  1992   0.29        243000    Diesel    Automatic         Lahore
# 11643  2022   0.35         32000    Hybrid    Automatic         Punjab
# 11686  2007   0.16         85000    Petrol    Automatic        Karachi
# 11763  2013   0.72         59000    Petrol    Automatic         Lahore
#
#         color  assembly  engine body_type  interior_scores  exterior_scores  \
# ...

# %%
df.groupby('color')['price'].mean().sort_values(ascending=False)
# Out:
# color
# Ivory        1.067333
# Black        0.773949
# Yellow       0.723750
# White        0.699438
# Teal         0.600000
# Burgundy     0.552609
# Graphite     0.522979
# Beige        0.493108
# Red          0.459674
# Grey         0.452522
# Orange       0.440000
# Blue         0.427136
# Brown        0.414848
# Maroon       0.411746
# Silver       0.407013
# Bronze       0.375849
# Purple       0.360000
# Titanium     0.341277
# Gold         0.325755
# Other        0.320000
# Champagne    0.300000
# Green        0.290569
# Pink         0.247273
# Charcoal     0.167778
# Name: price, dtype: float64

# %%
 df['color'] = df['color'].apply(lambda x:'other' if x not in ['White','Black','Silver','Grey','Blue'] else x)

# %%
df['color'].value_counts()
# Out:
# color
# White     4717
# Black     2808
# Silver    1754
# other     1646
# Grey       559
# Blue       433
# Name: count, dtype: int64

# %%
df['city'] = df['city'].apply(lambda x:'other' if x not in ['Islamabad','Punjab','Lahore','Karachi','Sindh','Un-Registered'] else x)

# %%
mapping = {'Lahore':'Punjab','Karachi':'Sindh'}
df['city'] = df['city'].replace(mapping)

# %%
(df.isnull().sum() / df.shape[0] )* 100
# Out:
# year               0.000000
# price              0.000000
# Km_travelled       0.000000
# fuel_type          0.000000
# transmission       0.000000
# city               0.000000
# color              0.000000
# assembly           0.000000
# engine             0.000000
# body_type          1.359403
# interior_scores    0.000000
# exterior_scores    0.000000
# safety_scores      0.000000
# comfort_scores     0.000000
# company            0.000000
# dtype: float64

# %%
df.head(1)
# Out:
#    year  price  Km_travelled fuel_type transmission   city  color  assembly  \
# 0  2020   0.64         50000    Petrol    Automatic  Sindh  White  Imported
#
#    engine  body_type  interior_scores  exterior_scores  safety_scores  \
# 0  2000.0  Crossover             34.0             30.0           38.0
#
#    comfort_scores company
# 0            42.0     KIA

# %%
df['body_type'].fillna(df['body_type'].mode()[0], inplace=True)

# %%
(df.isnull().sum() / df.shape[0] )* 100
# Out:
# year               0.0
# price              0.0
# Km_travelled       0.0
# fuel_type          0.0
# transmission       0.0
# city               0.0
# color              0.0
# assembly           0.0
# engine             0.0
# body_type          0.0
# interior_scores    0.0
# exterior_scores    0.0
# safety_scores      0.0
# comfort_scores     0.0
# company            0.0
# dtype: float64
